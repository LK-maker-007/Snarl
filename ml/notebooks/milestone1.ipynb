# %% [markdown]
# # Milestone 1 — convert, parity, latency
#
# Runs the on-device de-risking pipeline: builds the lightweight tracker, converts PyTorch → LiteRT/TFLite, checks PyTorch↔TFLite parity, and benchmarks host-CPU latency. A CPU runtime is fine for this small model. The parity and latency numbers are produced by the run below — they are not pre-asserted.

# %%
# !git clone --depth 1 https://github.com/LK-maker-007/Snarl.git
# %cd Snarl/ml
# !pip install -q -e '.[convert]'

# %%
# !python -m snarl_ml.milestone1
